# %% [markdown]
# # Ejercicios con numpy

# %%
import numpy as np

# %% [markdown]
# #### crear arreglo

# %%
mi_arreglo = np.array([1,2,3,4,5,6])

# %% [markdown]
# ## El maximo

# %%
mi_arreglo.max()
# Out:
# 6

# %%
mi_arreglo.sum()
# Out:
# 21

# %%
mi_arreglo.min()
# Out:
# 1

# %%
mi_arreglo + 1
# Out:
# array([2, 3, 4, 5, 6, 7])

# %%
mi_arreglo * 10
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
mi_arreglo[1] + 1
# Out:
# 3

# %%
mi_arreglo[:3]
# Out:
# array([1, 2, 3])

# %%
mi_arreglo ** 2
# Out:
# array([ 1,  4,  9, 16, 25, 36])

# %%
np.sin(mi_arreglo)
# Out:
# array([ 0.84147098,  0.90929743,  0.14112001, -0.7568025 , -0.95892427,
#        -0.2794155 ])

# %%
mi_arreglo.reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# ### El Reto

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sean x : [1,2,4,5,6]  y : [10, 12, 15 ,18, 21]
